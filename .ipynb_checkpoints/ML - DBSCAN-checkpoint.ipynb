# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import LabelEncoder

from sklearn import metrics

# %matplotlib inline

# %% [markdown]
# # Preprocess the Data

# %% [markdown]
# ## 1. Simple EDA + Data Quality checking

# %%
df = pd.read_csv("./Data/final_data.csv")

# %%
df.shape
# Out:
# (7136, 17)

# %%
df.head()
# Out:
#                 team              position  height  age  appearance     goals  \
# 0  Manchester United  Defender Centre-Back   175.0   25          82  0.028090
# 1  Manchester United  Defender Centre-Back   194.0   30          68  0.037799
# 2  Manchester United  Defender Centre-Back   187.0   28          70  0.000000
# 3  Manchester United  Defender Centre-Back   186.0   21          34  0.000000
# 4  Manchester United    Defender Left-Back   169.0   23          89  0.012619
#
#     assists  yellow cards  second yellow cards  red cards  goals conceded  \
# 0  0.056180      0.224719               0.0000        0.0             0.0
# 1  0.000000      0.302394               0.0189        0.0             0.0
# 2  0.032901      0.115153               0.0000        0.0             0.0
# 3  0.000000      0.130529               0.0000        0.0             0.0
# 4  0.063096      0.227145               0.0000        0.0             0.0
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0           0.0            6408           175             22      9
# 1           0.0            4762           148             27      1
# 2           0.0            5471            95             19     10
# 3           0.0            2758            47             13      0
# 4           0.0            7132           182             15      3
#
#    current_value
# 0       50000000
# 1       25000000
# 2       15000000
# 3        2000000
# 4       22000000

# %%
df.dtypes
# Out:
# team                    object
# position                object
# height                 float64
# age                      int64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# dtype: object

# %%
# Calculate the frequency of each 'team'
team_counts = df['team'].value_counts()

# Filter 'team' values that appear 2 or more times
df = df[df['team'].isin(team_counts[team_counts >= 2].index)]

# %%
df.shape
# Out:
# (7135, 17)

# %% [markdown]
# ## 2. Feature engineering

# %% [markdown]
# 1. Feature scaling
# 2. Aggregation
# 3. One hot coding

# %%
df.head(2)
# Out:
#                 team              position  height  age  appearance     goals  \
# 0  Manchester United  Defender Centre-Back   175.0   25          82  0.028090
# 1  Manchester United  Defender Centre-Back   194.0   30          68  0.037799
#
#    assists  yellow cards  second yellow cards  red cards  goals conceded  \
# 0  0.05618      0.224719               0.0000        0.0             0.0
# 1  0.00000      0.302394               0.0189        0.0             0.0
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0           0.0            6408           175             22      9
# 1           0.0            4762           148             27      1
#
#    current_value
# 0       50000000
# 1       25000000

# %%
# Select the relevant columns
df = df[['height', 'age', 'goals', 'assists', 'position']]

# %%
df = pd.get_dummies(df, columns=['position'])

# %%
df.shape
# Out:
# (7135, 20)

# %%
df.head(2)
# Out:
#    height  age     goals  assists  position_Attack  \
# 0   175.0   25  0.028090  0.05618            False
# 1   194.0   30  0.037799  0.00000            False
#
#    position_Attack Centre-Forward  position_Attack-LeftWinger  \
# 0                           False                       False
# 1                           False                       False
#
#    position_Attack-RightWinger  position_Attack-SecondStriker  \
# 0                        False                          False
# 1                        False                          False
#
#    position_Defender  position_Defender Centre-Back  \
# 0              False                           True
# 1              False                           True
#
#    position_Defender Left-Back  position_Defender Right-Back  \
# 0                        False                         False
# 1                        False                         False
#
#    position_Goalkeeper  position_midfield  \
# 0                False              False
# 1                False              False
#
#    position_midfield-AttackingMidfield  position_midfield-CentralMidfield  \
# 0                                False                              False
# 1                                False                              False
#
#    position_midfield-DefensiveMidfield  position_midfield-LeftMidfield  \
# 0                                False                           False
# 1                                False                           False
#
#    position_midfield-RightMidfield
# 0                            False
# 1                            False

# %% [markdown]
# ## Prepare train and test data

# %%
# Prepare data
X = df


# sacle the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (7135, 20)

# %% [markdown]
# # Buliding the Model

# %%
# 2. Use NearestNeighbors to find the optimal eps
min_samples = 2

# %%
nn = NearestNeighbors(n_neighbors=min_samples)
nn.fit(X_scaled)
distances, indices = nn.kneighbors(X_scaled)

# %%
distances[:,min_samples-1]
# Out:
# array([0.53504951, 0.1863216 , 0.20255625, ..., 0.28778896, 0.30229545,
#        0.45214787])

# %%
# The distance to the furthest neighbor (min_samples-th nearest) for each point
k_dist = distances[:, min_samples-1]

# Sort distances
k_dist_sorted = np.sort(k_dist)

# 3. Plotting the k-distance graph
plt.figure(figsize=(8, 6))
plt.plot(k_dist_sorted)
plt.title('K-Distance Graph')
plt.xlabel('Points sorted by distance')
plt.ylabel('k-distance (eps value)')
plt.grid(True)
plt.show()

# %%
# 4. Apply DBSCAN with chosen eps and min_samples
# Typically, you choose eps at the "elbow" point in this plot, where the slope changes significantly
chosen_eps = 0.7  # This is an example; choose this value based on the plot
dbscan = DBSCAN(eps=chosen_eps, min_samples=min_samples)

# %% [markdown]
# # Train the Model

# %%
# Fit the model on the training data

clusters = dbscan.fit_predict(X_scaled)

# %%
pd.Series(clusters).value_counts()
# Out:
# 0      1344
# 4       788
# 2       630
# 8       628
# 1       595
#        ...
# 67        2
# 66        2
# 65        2
# 64        2
# 161       2
# Name: count, Length: 163, dtype: int64

# %% [markdown]
# # Evaluating the Model

# %%
silhouette_avg = silhouette_score(X, clusters)
silhouette_avg
# Out:
# -0.7115711753552272

# %%
X.head(2)
# Out:
#    height  age     goals  assists  position_Attack  \
# 0   175.0   25  0.028090  0.05618            False
# 1   194.0   30  0.037799  0.00000            False
#
#    position_Attack Centre-Forward  position_Attack-LeftWinger  \
# 0                           False                       False
# 1                           False                       False
#
#    position_Attack-RightWinger  position_Attack-SecondStriker  \
# 0                        False                          False
# 1                        False                          False
#
#    position_Defender  position_Defender Centre-Back  \
# 0              False                           True
# 1              False                           True
#
#    position_Defender Left-Back  position_Defender Right-Back  \
# 0                        False                         False
# 1                        False                         False
#
#    position_Goalkeeper  position_midfield  \
# 0                False              False
# 1                False              False
#
#    position_midfield-AttackingMidfield  position_midfield-CentralMidfield  \
# 0                                False                              False
# 1                                False                              False
#
#    position_midfield-DefensiveMidfield  position_midfield-LeftMidfield  \
# 0                                False                           False
# 1                                False                           False
#
#    position_midfield-RightMidfield
# 0                            False
# 1                            False

# %%
# 5. Plot the clustering result
plt.figure(figsize=(8, 6))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis', s=50, edgecolor='k')
plt.title(f'DBSCAN Clustering with eps={chosen_eps}')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
X['dbscan'] = clusters

# %%
X['dbscan'].value_counts()
# Out:
# dbscan
# 0      1344
# 4       788
# 2       630
# 8       628
# 1       595
#        ...
# 67        2
# 66        2
# 65        2
# 64        2
# 161       2
# Name: count, Length: 163, dtype: int64

# %%
sns.scatterplot(data=X, x='height', y='age', hue = 'dbscan')
# Out:
# <Axes: xlabel='height', ylabel='age'>

# %%
sns.scatterplot(data=X, x='goals', y='assists', hue = 'dbscan')
# Out:
# <Axes: xlabel='goals', ylabel='assists'>
